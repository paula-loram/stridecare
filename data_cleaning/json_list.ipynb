# %%
import pandas as pd

# %%
df = pd.read_csv("data/meta/run_data_meta.csv")
df
# Out:
#       sub_id        datestring              filename   speed_r  age  Height  \
# 0     100433  2010-10-05 13:22  20101005T132240.json  1.610861   53     NaN
# 1     100434  2010-11-17 13:22  20101117T132240.json  2.237294   51     NaN
# 2     100537  2012-07-03 10:25  20120703T102550.json  2.127441  255   173.1
# 3     100560  2012-07-17 10:37  20120717T103748.json  2.657365   33   179.3
# 4     101481  2012-07-17 10:50  20120717T105021.json  2.625088   32   176.3
# ...      ...               ...                   ...       ...  ...     ...
# 1827  200986  2015-03-12 14:28  20150312T143944.json  4.876998   20   174.0
# 1828  200987  2015-03-12 16:08  20150312T160840.json  2.765022   50   164.0
# 1829  201100  2015-04-09 15:59  20150409T155915.json  2.790966   52   170.0
# 1830  201101  2015-04-13 14:31  20150413T143152.json  2.828602   21   162.0
# 1831  201099   2015-04-14 9:20  20150414T092041.json  2.514918   57   165.5
#
# ...

# %%
filenames= []
for i in range(len(df)):
    filenames.append(f"{df.loc[i, 'sub_id']}/{df.loc[i,'filename']}")

# %%
filenames
# Out:
# ['100433/20101005T132240.json',
#  '100434/20101117T132240.json',
#  '100537/20120703T102550.json',
#  '100560/20120717T103748.json',
#  '101481/20120717T105021.json',
#  '100591/20120809T100115.json',
#  '100595/20120829T125604.json',
#  '100646/20121101T095248.json',
#  '100658/20121122T140316.json',
#  '100671/20121213T105755.json',
#  '100727/20130410T105446.json',
#  '100767/20130606T134651.json',
#  '100776/20130620T121501.json',
#  '100816/20130806T105329.json',
#  '100824/20130904T115007.json',
#  '100825/20130910T105157.json',
#  '100842/20130917T114750.json',
#  '100843/20130924T105459.json',
#  '100844/20130924T115413.json',
#  '100865/20131105T103758.json',
#  '100882/20131126T104419.json',
#  '100883/20131127T115511.json',
#  '100899/20140116T125000.json',
#  '100945/20140205T110432.json',
#  '100072/20110713T114725.json',
#  '100230/20110929T094056.json',
#  '100344/20111116T124303.json',
#  '100418/20120118T113903.json',
#  '100419/20120327T114407.json',
# ...
