# %%
from google.cloud import storage
from google.cloud import bigquery
import pandas as pd
import os
import datetime
from training_data_angles import analyze_gait_data

# %% [markdown]
# ## Notebook aim

# %% [markdown]
# The aim of this notebook is to load from bigquery the .json files containing the coordinates for runners, then obtain the angles using the function in training_data_angles.py, to output each one into a new folder in bigquery.

# %% [markdown]
# ### Creating list of filenames to loop through

# %%
jsons = pd.read_csv("data/meta/run_data_meta.csv")

json_filenames = []
for i in range(len(jsons)):
    json_filenames.append(f"{jsons.loc[i, 'sub_id']}/{jsons.loc[i,'filename']}")

# %% [markdown]
# ### Google Cloud Set-up

# %%
# Input bucket name
GCS_INPUT_BUCKET_NAME = 'stridecare'
GCS_INPUT_PREFIX = 'RunInjuryClinic/' 

# Initialize GCS client
gcs_client = storage.Client()

#Output to bigquery
BQ_PROJECT_ID = 'stridecare-461809'
BQ_DATASET_ID = 'angle_csvs'

#output to local data folder
LOCAL_OUTPUT_BASE_DIR = './processed_angles_data'

# Temporary directory to download JSON files to
LOCAL_TEMP_JSON_DIR = f"temp_gait_json_files_{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}"
os.makedirs(LOCAL_TEMP_JSON_DIR, exist_ok=True) # Create the directory if it doesn't exist

# Initialize GCS and BigQuery clients
gcs_client = storage.Client()
bq_client = bigquery.Client(project=BQ_PROJECT_ID)

print(f"Starting gait analysis pipeline for GCS input bucket: {GCS_INPUT_BUCKET_NAME}/{GCS_INPUT_PREFIX}")
print(f"Processed angles will be uploaded to BigQuery dataset: {BQ_PROJECT_ID}.{BQ_DATASET_ID}")
print(f"Processed CSVs will also be saved locally to: {LOCAL_OUTPUT_BASE_DIR}")
# Out:
# Starting gait analysis pipeline for GCS input bucket: stridecare/RunInjuryClinic/
# Processed angles will be uploaded to BigQuery dataset: stridecare-461809.angle_csvs
# Processed CSVs will also be saved locally to: ./processed_angles_data

# %% [markdown]
# ### Safety check

# %%
try:
    input_bucket = gcs_client.bucket(GCS_INPUT_BUCKET_NAME)

    # Ensure the BigQuery dataset exists
    try:
        bq_client.get_dataset(BQ_DATASET_ID)
        print(f"BigQuery Dataset '{BQ_DATASET_ID}' already exists.")
    except Exception: # Catching a general exception if dataset not found, BigQuery raises NotFound
        print(f"BigQuery Dataset '{BQ_DATASET_ID}' not found. Creating it...")
        dataset = bigquery.Dataset(f"{BQ_PROJECT_ID}.{BQ_DATASET_ID}")
        dataset.location = "EU" # Or your desired location (e.g., "US", "asia-east1")
        bq_client.create_dataset(dataset, timeout=30)
        print(f"BigQuery Dataset '{BQ_DATASET_ID}' created successfully.")


#json filenames to process 

    json_files_to_process = []
    for json_file in json_filenames:
        parts = json_file.split('/')
        if len(parts) >= 2:
            json_files_to_process.append({"sub_id": parts[-2], "json_file": parts[-1]})
        else:
            print(f"Warning: Skipping invalid path format in list: {json_file}")

    if not json_files_to_process:
        print("No JSON files specified in 'json_files_to_process'. Please ensure your list is populated.")
    
    processed_files_count = 0
    
    for entry in json_files_to_process:
        sub_id = entry.get("sub_id")
        json_filename = entry.get("json_file")

        if not sub_id or not json_filename:
            print(f"Skipping invalid entry in list: {entry}")
            continue

        # Construct the full storage path for the input JSON file in GCS
        gcs_input_blob_path = f"{GCS_INPUT_PREFIX}{sub_id}/{json_filename}"
        
        print(f"\nProcessing GCS blob: {gcs_input_blob_path}")
        local_json_filepath = os.path.join(LOCAL_TEMP_JSON_DIR, json_filename)
        
        try:
            # Download the JSON file locally
            input_blob = input_bucket.blob(gcs_input_blob_path)
            input_blob.download_to_filename(local_json_filepath)
            print(f"Downloaded '{gcs_input_blob_path}' to '{local_json_filepath}'")

            # Process the file using the imported analyze_gait_data function
            angles_df = analyze_gait_data(local_json_filepath)

            if not angles_df.empty:
                base_json_name = os.path.splitext(json_filename)[0] # e.g., "20110531T161051"
                
                # --- 1. Save to local data folder (as CSV) ---
                local_output_sub_dir = os.path.join(LOCAL_OUTPUT_BASE_DIR, sub_id)
                os.makedirs(local_output_sub_dir, exist_ok=True) # Create sub_id folder locally
                local_csv_filename = f"{base_json_name}_angles.csv"
                local_csv_filepath = os.path.join(local_output_sub_dir, local_csv_filename)
                
                angles_df.to_csv(local_csv_filepath, index=False)
                print(f"Saved angles locally to: '{local_csv_filepath}'")

                # --- 2. Upload to BigQuery (as a new table) ---
                # BigQuery table names must start with a letter or underscore and contain
                # only letters, numbers, and underscores. Replace any invalid chars.
                bq_table_name = f"angles_{base_json_name.replace('.', '_').replace('-', '_')}"
                bq_table_id = f"{BQ_PROJECT_ID}.{BQ_DATASET_ID}.{bq_table_name}"
                
                # Configure BigQuery load job (e.g., overwrite existing table if it has the same name)
                job_config = bigquery.LoadJobConfig(
                    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE, # Overwrites if table exists
                    # Consider WRITE_APPEND if you want to add rows to an existing table with the same schema
                    # or WRITE_EMPTY if you want the job to fail if the table already exists.
                )

                load_job = bq_client.load_table_from_dataframe(
                    angles_df, bq_table_id, job_config=job_config
                )
                load_job.result() # Wait for the job to complete
                
                print(f"Uploaded angles to BigQuery table: '{bq_table_id}'")
                processed_files_count += 1
            else:
                print(f"  '{json_filename}': No angle data returned by analyze_gait_data. Skipping all outputs.")

        except Exception as e:
            print(f"Error processing '{gcs_input_blob_path}': {e}")
        finally:
            # Clean up: remove the downloaded JSON file
            if os.path.exists(local_json_filepath):
                os.remove(local_json_filepath)
                print(f"Cleaned up local temporary JSON file: '{local_json_filepath}'")

except Exception as e:
    print(f"An unhandled error occurred: {e}")
finally:
    # Clean up the temporary local JSON download directory
    if os.path.exists(LOCAL_TEMP_JSON_DIR):
        try:
            os.rmdir(LOCAL_TEMP_JSON_DIR) # Will only remove if empty
            print(f"Cleaned up temporary JSON download directory: '{LOCAL_TEMP_JSON_DIR}'")
        except OSError:
            print(f"Warning: Could not remove non-empty temporary JSON directory: '{LOCAL_TEMP_JSON_DIR}'. Please remove manually if empty.")

print(f"\nProcessing complete. Total files processed and outputted: {processed_files_count}")
# Out:
# BigQuery Dataset 'angle_csvs' already exists.
#
# Processing GCS blob: RunInjuryClinic/100433/20101005T132240.json
# Downloaded 'RunInjuryClinic/100433/20101005T132240.json' to 'temp_gait_json_files_20250605210341/20101005T132240.json'
# Saved angles locally to: './processed_angles_data/100433/20101005T132240_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20101005T132240'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20101005T132240.json'
#
# Processing GCS blob: RunInjuryClinic/100434/20101117T132240.json
# Downloaded 'RunInjuryClinic/100434/20101117T132240.json' to 'temp_gait_json_files_20250605210341/20101117T132240.json'
# Saved angles locally to: './processed_angles_data/100434/20101117T132240_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20101117T132240'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20101117T132240.json'
#
# Processing GCS blob: RunInjuryClinic/100537/20120703T102550.json
# Downloaded 'RunInjuryClinic/100537/20120703T102550.json' to 'temp_gait_json_files_20250605210341/20120703T102550.json'
# Saved angles locally to: './processed_angles_data/100537/20120703T102550_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120703T102550'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120703T102550.json'
#
# Processing GCS blob: RunInjuryClinic/100560/20120717T103748.json
# Downloaded 'RunInjuryClinic/100560/20120717T103748.json' to 'temp_gait_json_files_20250605210341/20120717T103748.json'
# Saved angles locally to: './processed_angles_data/100560/20120717T103748_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120717T103748'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120717T103748.json'
#
# Processing GCS blob: RunInjuryClinic/101481/20120717T105021.json
# Downloaded 'RunInjuryClinic/101481/20120717T105021.json' to 'temp_gait_json_files_20250605210341/20120717T105021.json'
# Saved angles locally to: './processed_angles_data/101481/20120717T105021_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120717T105021'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120717T105021.json'
#
# Processing GCS blob: RunInjuryClinic/100591/20120809T100115.json
# Downloaded 'RunInjuryClinic/100591/20120809T100115.json' to 'temp_gait_json_files_20250605210341/20120809T100115.json'
# Saved angles locally to: './processed_angles_data/100591/20120809T100115_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120809T100115'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120809T100115.json'
#
# Processing GCS blob: RunInjuryClinic/100595/20120829T125604.json
# Downloaded 'RunInjuryClinic/100595/20120829T125604.json' to 'temp_gait_json_files_20250605210341/20120829T125604.json'
# Saved angles locally to: './processed_angles_data/100595/20120829T125604_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120829T125604'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120829T125604.json'
#
# Processing GCS blob: RunInjuryClinic/100646/20121101T095248.json
# Downloaded 'RunInjuryClinic/100646/20121101T095248.json' to 'temp_gait_json_files_20250605210341/20121101T095248.json'
# Saved angles locally to: './processed_angles_data/100646/20121101T095248_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20121101T095248'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20121101T095248.json'
#
# Processing GCS blob: RunInjuryClinic/100658/20121122T140316.json
# Downloaded 'RunInjuryClinic/100658/20121122T140316.json' to 'temp_gait_json_files_20250605210341/20121122T140316.json'
# Saved angles locally to: './processed_angles_data/100658/20121122T140316_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20121122T140316'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20121122T140316.json'
#
# Processing GCS blob: RunInjuryClinic/100671/20121213T105755.json
# Downloaded 'RunInjuryClinic/100671/20121213T105755.json' to 'temp_gait_json_files_20250605210341/20121213T105755.json'
# Saved angles locally to: './processed_angles_data/100230/20110929T094056_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20110929T094056'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20110929T094056.json'
#
# Processing GCS blob: RunInjuryClinic/100344/20111116T124303.json
# Downloaded 'RunInjuryClinic/100344/20111116T124303.json' to 'temp_gait_json_files_20250605210341/20111116T124303.json'
# Saved angles locally to: './processed_angles_data/100344/20111116T124303_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20111116T124303'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20111116T124303.json'
#
# Processing GCS blob: RunInjuryClinic/100418/20120118T113903.json
# Downloaded 'RunInjuryClinic/100418/20120118T113903.json' to 'temp_gait_json_files_20250605210341/20120118T113903.json'
# Saved angles locally to: './processed_angles_data/100418/20120118T113903_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120118T113903'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120118T113903.json'
#
# Processing GCS blob: RunInjuryClinic/100419/20120327T114407.json
# Downloaded 'RunInjuryClinic/100419/20120327T114407.json' to 'temp_gait_json_files_20250605210341/20120327T114407.json'
# Saved angles locally to: './processed_angles_data/100419/20120327T114407_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120327T114407'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120327T114407.json'
#
# Processing GCS blob: RunInjuryClinic/100420/20120508T105413.json
# Downloaded 'RunInjuryClinic/100420/20120508T105413.json' to 'temp_gait_json_files_20250605210341/20120508T105413.json'
# Saved angles locally to: './processed_angles_data/100420/20120508T105413_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120508T105413'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120508T105413.json'
#
# Processing GCS blob: RunInjuryClinic/100082/20110126T125910.json
# Downloaded 'RunInjuryClinic/100082/20110126T125910.json' to 'temp_gait_json_files_20250605210341/20110126T125910.json'
# Saved angles locally to: './processed_angles_data/100082/20110126T125910_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20110126T125910'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20110126T125910.json'
#
# Processing GCS blob: RunInjuryClinic/100065/20110609T103144.json
# Downloaded 'RunInjuryClinic/100065/20110609T103144.json' to 'temp_gait_json_files_20250605210341/20110609T103144.json'
# Saved angles locally to: './processed_angles_data/100065/20110609T103144_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20110609T103144'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20110609T103144.json'
#
# Processing GCS blob: RunInjuryClinic/100056/20110628T105139.json
# Downloaded 'RunInjuryClinic/100056/20110628T105139.json' to 'temp_gait_json_files_20250605210341/20110628T105139.json'
# Saved angles locally to: './processed_angles_data/100056/20110628T105139_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20110628T105139'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20110628T105139.json'
#
# Processing GCS blob: RunInjuryClinic/101054/20140410T152849.json
# Downloaded 'RunInjuryClinic/101054/20140410T152849.json' to 'temp_gait_json_files_20250605210341/20140410T152849.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140410T152849.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140324T102916.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101017/20140324T102916_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140324T102916'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140324T102916.json'
#
# Processing GCS blob: RunInjuryClinic/101782/20160205T083943.json
# Downloaded 'RunInjuryClinic/101782/20160205T083943.json' to 'temp_gait_json_files_20250605210341/20160205T083943.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20160205T083943.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101782/20160205T083943_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160205T083943'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160205T083943.json'
#
# Processing GCS blob: RunInjuryClinic/101683/20160224T082034.json
# Downloaded 'RunInjuryClinic/101683/20160224T082034.json' to 'temp_gait_json_files_20250605210341/20160224T082034.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20160224T082034.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101683/20160224T082034_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160224T082034'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160224T082034.json'
#
# Processing GCS blob: RunInjuryClinic/101058/20140414T094847.json
# Downloaded 'RunInjuryClinic/101058/20140414T094847.json' to 'temp_gait_json_files_20250605210341/20140414T094847.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140414T094847.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101058/20140414T094847_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140414T094847'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140414T094847.json'
#
# Processing GCS blob: RunInjuryClinic/101047/20140331T103844.json
# Downloaded 'RunInjuryClinic/101047/20140331T103844.json' to 'temp_gait_json_files_20250605210341/20140331T103844.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140331T103844.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101047/20140331T103844_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140331T103844'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140331T103844.json'
#
# Processing GCS blob: RunInjuryClinic/101067/20140402T132349.json
# Downloaded 'RunInjuryClinic/101067/20140402T132349.json' to 'temp_gait_json_files_20250605210341/20140402T132349.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140402T132349.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101067/20140402T132349_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140402T132349'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140402T132349.json'
#
# Processing GCS blob: RunInjuryClinic/101107/20140523T113613.json
# Downloaded 'RunInjuryClinic/101107/20140523T113613.json' to 'temp_gait_json_files_20250605210341/20140523T113613.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140523T113613.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101107/20140523T113613_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140523T113613'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140523T113613.json'
#
# Processing GCS blob: RunInjuryClinic/101056/20140411T092355.json
# Downloaded 'RunInjuryClinic/101056/20140411T092355.json' to 'temp_gait_json_files_20250605210341/20140411T092355.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140411T092355.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101056/20140411T092355_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140411T092355'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140411T092355.json'
#
# Processing GCS blob: RunInjuryClinic/101055/20140410T160801.json
# Downloaded 'RunInjuryClinic/101055/20140410T160801.json' to 'temp_gait_json_files_20250605210341/20140410T160801.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140410T160801.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101055/20140410T160801_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140410T160801'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140410T160801.json'
#
# Processing GCS blob: RunInjuryClinic/100765/20160613T124827.json
# Downloaded 'RunInjuryClinic/100765/20160613T124827.json' to 'temp_gait_json_files_20250605210341/20160613T124827.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20160613T124827.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/100765/20160613T124827_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160613T124827'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160613T124827.json'
#
# Processing GCS blob: RunInjuryClinic/101613/20151008T130905.json
# Downloaded 'RunInjuryClinic/101613/20151008T130905.json' to 'temp_gait_json_files_20250605210341/20151008T130905.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20151008T130905.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101613/20151008T130905_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20151008T130905'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20151008T130905.json'
#
# Processing GCS blob: RunInjuryClinic/101098/20140513T164936.json
# Downloaded 'RunInjuryClinic/101098/20140513T164936.json' to 'temp_gait_json_files_20250605210341/20140513T164936.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140513T164936.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101098/20140513T164936_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140513T164936'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140513T164936.json'
#
# Processing GCS blob: RunInjuryClinic/101050/20140408T132129.json
# Downloaded 'RunInjuryClinic/101050/20140408T132129.json' to 'temp_gait_json_files_20250605210341/20140408T132129.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140408T132129.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101050/20140408T132129_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140408T132129'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140408T132129.json'
#
# Processing GCS blob: RunInjuryClinic/101048/20140331T141326.json
# Downloaded 'RunInjuryClinic/101048/20140331T141326.json' to 'temp_gait_json_files_20250605210341/20140331T141326.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140331T141326.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101048/20140331T141326_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140331T141326'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140331T141326.json'
#
# Processing GCS blob: RunInjuryClinic/101068/20140407T102830.json
# Downloaded 'RunInjuryClinic/101068/20140407T102830.json' to 'temp_gait_json_files_20250605210341/20140407T102830.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140407T102830.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101068/20140407T102830_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20140407T102830'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20140407T102830.json'
#
# Processing GCS blob: RunInjuryClinic/101072/20140424T122129.json
# Downloaded 'RunInjuryClinic/101072/20140424T122129.json' to 'temp_gait_json_files_20250605210341/20140424T122129.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140424T122129.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101573/20150820T112021_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150820T112021'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150820T112021.json'
#
# Processing GCS blob: RunInjuryClinic/101079/20140429T151750.json
# Downloaded 'RunInjuryClinic/101079/20140429T151750.json' to 'temp_gait_json_files_20250605210341/20140429T151750.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20140429T151750.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101692/20160307T170325_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160307T170325'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160307T170325.json'
#
# Processing GCS blob: RunInjuryClinic/101688/20160303T105848.json
# Downloaded 'RunInjuryClinic/101688/20160303T105848.json' to 'temp_gait_json_files_20250605210341/20160303T105848.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20160303T105848.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101385/20150324T133503_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150324T133503'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150324T133503.json'
#
# Processing GCS blob: RunInjuryClinic/101412/20150330T121659.json
# Downloaded 'RunInjuryClinic/101412/20150330T121659.json' to 'temp_gait_json_files_20250605210341/20150330T121659.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150330T121659.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150302T114239'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150302T114239.json'
#
# Processing GCS blob: RunInjuryClinic/101405/20150302T114638.json
# Downloaded 'RunInjuryClinic/101405/20150302T114638.json' to 'temp_gait_json_files_20250605210341/20150302T114638.json'
# Saved angles locally to: './processed_angles_data/100600/20120906T120315_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120906T120315'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120906T120315.json'
#
# Processing GCS blob: RunInjuryClinic/100602/20120911T123510.json
# Downloaded 'RunInjuryClinic/100602/20120911T123510.json' to 'temp_gait_json_files_20250605210341/20120911T123510.json'
# Saved angles locally to: './processed_angles_data/100733/20130416T120045_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20130416T120045'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20130416T120045.json'
#
# Processing GCS blob: RunInjuryClinic/100734/20130417T100009.json
# Downloaded 'RunInjuryClinic/100734/20130417T100009.json' to 'temp_gait_json_files_20250605210341/20130417T100009.json'
# Saved angles locally to: './processed_angles_data/100771/20130619T101217_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20130619T101217'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20130619T101217.json'
#
# Processing GCS blob: RunInjuryClinic/100772/20130619T121352.json
# Downloaded 'RunInjuryClinic/100772/20130619T121352.json' to 'temp_gait_json_files_20250605210341/20130619T121352.json'
# Saved angles locally to: './processed_angles_data/100854/20131001T120943_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20131001T120943'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20131001T120943.json'
#
# Processing GCS blob: RunInjuryClinic/100855/20131017T121017.json
# Downloaded 'RunInjuryClinic/100855/20131017T121017.json' to 'temp_gait_json_files_20250605210341/20131017T121017.json'
# Saved angles locally to: './processed_angles_data/101436/20150430T141737_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150430T141737'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150430T141737.json'
#
# Processing GCS blob: RunInjuryClinic/101437/20150512T070637.json
# Downloaded 'RunInjuryClinic/101437/20150512T070637.json' to 'temp_gait_json_files_20250605210341/20150512T070637.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150512T070637.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101437/20150512T070637_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150512T070637'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150512T070637.json'
#
# Processing GCS blob: RunInjuryClinic/101449/20150530T134336.json
# Downloaded 'RunInjuryClinic/101449/20150530T134336.json' to 'temp_gait_json_files_20250605210341/20150530T134336.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150530T134336.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101449/20150530T134336_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150530T134336'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150530T134336.json'
#
# Processing GCS blob: RunInjuryClinic/101511/20150608T153054.json
# Downloaded 'RunInjuryClinic/101511/20150608T153054.json' to 'temp_gait_json_files_20250605210341/20150608T153054.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150608T153054.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101511/20150608T153054_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150608T153054'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150608T153054.json'
#
# Processing GCS blob: RunInjuryClinic/101511/20150609T152003.json
# Downloaded 'RunInjuryClinic/101511/20150609T152003.json' to 'temp_gait_json_files_20250605210341/20150609T152003.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150609T152003.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101511/20150609T152003_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150609T152003'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150609T152003.json'
#
# Processing GCS blob: RunInjuryClinic/101511/20150609T152508.json
# Downloaded 'RunInjuryClinic/101511/20150609T152508.json' to 'temp_gait_json_files_20250605210341/20150609T152508.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150609T152508.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101511/20150609T152508_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150609T152508'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150609T152508.json'
#
# Processing GCS blob: RunInjuryClinic/101523/20150611T112033.json
# Downloaded 'RunInjuryClinic/101523/20150611T112033.json' to 'temp_gait_json_files_20250605210341/20150611T112033.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150611T112033.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101523/20150611T112033_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150611T112033'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150611T112033.json'
#
# Processing GCS blob: RunInjuryClinic/101596/20150921T132732.json
# Downloaded 'RunInjuryClinic/101596/20150921T132732.json' to 'temp_gait_json_files_20250605210341/20150921T132732.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150921T132732.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101596/20150921T132732_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150921T132732'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150921T132732.json'
#
# Processing GCS blob: RunInjuryClinic/101596/20151029T135520.json
# Downloaded 'RunInjuryClinic/101596/20151029T135520.json' to 'temp_gait_json_files_20250605210341/20151029T135520.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20151029T135520.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101596/20151029T135520_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20151029T135520'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20151029T135520.json'
#
# Processing GCS blob: RunInjuryClinic/101596/20151102T152457.json
# Downloaded 'RunInjuryClinic/101596/20151102T152457.json' to 'temp_gait_json_files_20250605210341/20151102T152457.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20151102T152457.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101596/20151102T152457_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20151102T152457'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20151102T152457.json'
#
# Processing GCS blob: RunInjuryClinic/101596/20151103T143343.json
# Downloaded 'RunInjuryClinic/101596/20151103T143343.json' to 'temp_gait_json_files_20250605210341/20151103T143343.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20151103T143343.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101596/20151103T143343_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20151103T143343'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20151103T143343.json'
#
# Processing GCS blob: RunInjuryClinic/101612/20151008T094601.json
# Downloaded 'RunInjuryClinic/101612/20151008T094601.json' to 'temp_gait_json_files_20250605210341/20151008T094601.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20151008T094601.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101612/20151008T094601_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20151008T094601'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20151008T094601.json'
#
# Processing GCS blob: RunInjuryClinic/101386/20150324T154709.json
# Downloaded 'RunInjuryClinic/101386/20150324T154709.json' to 'temp_gait_json_files_20250605210341/20150324T154709.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150324T154709.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/101386/20150324T154709_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150324T154709'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150324T154709.json'
#
# Processing GCS blob: RunInjuryClinic/101497/20160229T102427.json
# Downloaded 'RunInjuryClinic/101497/20160229T102427.json' to 'temp_gait_json_files_20250605210341/20160229T102427.json'
# Saved angles locally to: './processed_angles_data/101497/20160229T102427_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160229T102427'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160229T102427.json'
#
# Processing GCS blob: RunInjuryClinic/101497/20160307T104630.json
# Downloaded 'RunInjuryClinic/101497/20160307T104630.json' to 'temp_gait_json_files_20250605210341/20160307T104630.json'
# Saved angles locally to: './processed_angles_data/101497/20160307T104630_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160307T104630'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160307T104630.json'
#
# Processing GCS blob: RunInjuryClinic/101498/20160307T104430.json
# Downloaded 'RunInjuryClinic/101498/20160307T104430.json' to 'temp_gait_json_files_20250605210341/20160307T104430.json'
# Saved angles locally to: './processed_angles_data/101498/20160307T104430_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160307T104430'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160307T104430.json'
#
# Processing GCS blob: RunInjuryClinic/101498/20160314T122858.json
# Downloaded 'RunInjuryClinic/101498/20160314T122858.json' to 'temp_gait_json_files_20250605210341/20160314T122858.json'
# Saved angles locally to: './processed_angles_data/101498/20160314T122858_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160314T122858'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160314T122858.json'
#
# Processing GCS blob: RunInjuryClinic/101499/20160310T123556.json
# Downloaded 'RunInjuryClinic/101499/20160310T123556.json' to 'temp_gait_json_files_20250605210341/20160310T123556.json'
# Saved angles locally to: './processed_angles_data/101499/20160310T123556_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160310T123556'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160310T123556.json'
#
# Processing GCS blob: RunInjuryClinic/101499/20160317T124459.json
# Downloaded 'RunInjuryClinic/101499/20160317T124459.json' to 'temp_gait_json_files_20250605210341/20160317T124459.json'
# Saved angles locally to: './processed_angles_data/101499/20160317T124459_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160317T124459'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160317T124459.json'
#
# Processing GCS blob: RunInjuryClinic/101500/20160322T105330.json
# Downloaded 'RunInjuryClinic/101500/20160322T105330.json' to 'temp_gait_json_files_20250605210341/20160322T105330.json'
# Saved angles locally to: './processed_angles_data/101500/20160322T105330_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160322T105330'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160322T105330.json'
#
# Processing GCS blob: RunInjuryClinic/101500/20160329T121819.json
# Downloaded 'RunInjuryClinic/101500/20160329T121819.json' to 'temp_gait_json_files_20250605210341/20160329T121819.json'
# Saved angles locally to: './processed_angles_data/101500/20160329T121819_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160329T121819'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160329T121819.json'
#
# Processing GCS blob: RunInjuryClinic/101501/20160324T104017.json
# Downloaded 'RunInjuryClinic/101501/20160324T104017.json' to 'temp_gait_json_files_20250605210341/20160324T104017.json'
# Saved angles locally to: './processed_angles_data/101501/20160324T104017_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160324T104017'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160324T104017.json'
#
# Processing GCS blob: RunInjuryClinic/101501/20160331T114134.json
# Downloaded 'RunInjuryClinic/101501/20160331T114134.json' to 'temp_gait_json_files_20250605210341/20160331T114134.json'
# Saved angles locally to: './processed_angles_data/101501/20160331T114134_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160331T114134'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160331T114134.json'
#
# Processing GCS blob: RunInjuryClinic/101502/20160324T114646.json
# Downloaded 'RunInjuryClinic/101502/20160324T114646.json' to 'temp_gait_json_files_20250605210341/20160324T114646.json'
# Saved angles locally to: './processed_angles_data/101502/20160324T114646_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160324T114646'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160324T114646.json'
#
# Processing GCS blob: RunInjuryClinic/101502/20160331T113446.json
# Downloaded 'RunInjuryClinic/101502/20160331T113446.json' to 'temp_gait_json_files_20250605210341/20160331T113446.json'
# Saved angles locally to: './processed_angles_data/101502/20160331T113446_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160331T113446'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160331T113446.json'
#
# Processing GCS blob: RunInjuryClinic/101503/20160330T123035.json
# Downloaded 'RunInjuryClinic/101503/20160330T123035.json' to 'temp_gait_json_files_20250605210341/20160330T123035.json'
# Saved angles locally to: './processed_angles_data/101503/20160330T123035_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160330T123035'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160330T123035.json'
#
# Processing GCS blob: RunInjuryClinic/101503/20160406T101922.json
# Downloaded 'RunInjuryClinic/101503/20160406T101922.json' to 'temp_gait_json_files_20250605210341/20160406T101922.json'
# Saved angles locally to: './processed_angles_data/101503/20160406T101922_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160406T101922'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160406T101922.json'
#
# Processing GCS blob: RunInjuryClinic/101504/20160405T101635.json
# Downloaded 'RunInjuryClinic/101504/20160405T101635.json' to 'temp_gait_json_files_20250605210341/20160405T101635.json'
# Saved angles locally to: './processed_angles_data/101504/20160405T101635_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160405T101635'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160405T101635.json'
#
# Processing GCS blob: RunInjuryClinic/101504/20160412T121345.json
# Downloaded 'RunInjuryClinic/101504/20160412T121345.json' to 'temp_gait_json_files_20250605210341/20160412T121345.json'
# Saved angles locally to: './processed_angles_data/101504/20160412T121345_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160412T121345'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160412T121345.json'
#
# Processing GCS blob: RunInjuryClinic/101505/20160414T123749.json
# Downloaded 'RunInjuryClinic/101505/20160414T123749.json' to 'temp_gait_json_files_20250605210341/20160414T123749.json'
# Saved angles locally to: './processed_angles_data/101505/20160414T123749_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160414T123749'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160414T123749.json'
#
# Processing GCS blob: RunInjuryClinic/101505/20160421T114145.json
# Downloaded 'RunInjuryClinic/101505/20160421T114145.json' to 'temp_gait_json_files_20250605210341/20160421T114145.json'
# Saved angles locally to: './processed_angles_data/101505/20160421T114145_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160421T114145'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160421T114145.json'
#
# Processing GCS blob: RunInjuryClinic/101506/20160419T112544.json
# Downloaded 'RunInjuryClinic/101506/20160419T112544.json' to 'temp_gait_json_files_20250605210341/20160419T112544.json'
# Saved angles locally to: './processed_angles_data/101506/20160419T112544_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160419T112544'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160419T112544.json'
#
# Processing GCS blob: RunInjuryClinic/101506/20160426T111225.json
# Downloaded 'RunInjuryClinic/101506/20160426T111225.json' to 'temp_gait_json_files_20250605210341/20160426T111225.json'
# Saved angles locally to: './processed_angles_data/101506/20160426T111225_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160426T111225'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160426T111225.json'
#
# Processing GCS blob: RunInjuryClinic/101507/20160422T124126.json
# Downloaded 'RunInjuryClinic/101507/20160422T124126.json' to 'temp_gait_json_files_20250605210341/20160422T124126.json'
# Saved angles locally to: './processed_angles_data/101507/20160422T124126_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160422T124126'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160422T124126.json'
#
# Processing GCS blob: RunInjuryClinic/101507/20160429T104438.json
# Downloaded 'RunInjuryClinic/101507/20160429T104438.json' to 'temp_gait_json_files_20250605210341/20160429T104438.json'
# Saved angles locally to: './processed_angles_data/101507/20160429T104438_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160429T104438'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160429T104438.json'
#
# Processing GCS blob: RunInjuryClinic/101508/20160425T105521.json
# Downloaded 'RunInjuryClinic/101508/20160425T105521.json' to 'temp_gait_json_files_20250605210341/20160425T105521.json'
# Saved angles locally to: './processed_angles_data/101508/20160425T105521_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160425T105521'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160425T105521.json'
#
# Processing GCS blob: RunInjuryClinic/101508/20160502T101632.json
# Downloaded 'RunInjuryClinic/101508/20160502T101632.json' to 'temp_gait_json_files_20250605210341/20160502T101632.json'
# Saved angles locally to: './processed_angles_data/101508/20160502T101632_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160502T101632'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160502T101632.json'
#
# Processing GCS blob: RunInjuryClinic/101809/20160812T122556.json
# Downloaded 'RunInjuryClinic/101809/20160812T122556.json' to 'temp_gait_json_files_20250605210341/20160812T122556.json'
# Saved angles locally to: './processed_angles_data/101809/20160812T122556_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160812T122556'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160812T122556.json'
#
# Processing GCS blob: RunInjuryClinic/101807/20160812T111715.json
# Downloaded 'RunInjuryClinic/101807/20160812T111715.json' to 'temp_gait_json_files_20250605210341/20160812T111715.json'
# Saved angles locally to: './processed_angles_data/101807/20160812T111715_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20160812T111715'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20160812T111715.json'
#
# Processing GCS blob: RunInjuryClinic/100425/20120522T121758.json
# Downloaded 'RunInjuryClinic/100425/20120522T121758.json' to 'temp_gait_json_files_20250605210341/20120522T121758.json'
# Saved angles locally to: './processed_angles_data/100425/20120522T121758_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120522T121758'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120522T121758.json'
#
# Processing GCS blob: RunInjuryClinic/100413/20120524T105624.json
# Downloaded 'RunInjuryClinic/100413/20120524T105624.json' to 'temp_gait_json_files_20250605210341/20120524T105624.json'
# Saved angles locally to: './processed_angles_data/100413/20120524T105624_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120524T105624'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120524T105624.json'
#
# Processing GCS blob: RunInjuryClinic/100558/20120528T103155.json
# Downloaded 'RunInjuryClinic/100558/20120528T103155.json' to 'temp_gait_json_files_20250605210341/20120528T103155.json'
# Saved angles locally to: './processed_angles_data/100558/20120528T103155_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120528T103155'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120528T103155.json'
#
# Processing GCS blob: RunInjuryClinic/100583/20120605T115027.json
# Downloaded 'RunInjuryClinic/100583/20120605T115027.json' to 'temp_gait_json_files_20250605210341/20120605T115027.json'
# Saved angles locally to: './processed_angles_data/100583/20120605T115027_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120605T115027'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120605T115027.json'
#
# Processing GCS blob: RunInjuryClinic/100584/20120605T124837.json
# Downloaded 'RunInjuryClinic/100584/20120605T124837.json' to 'temp_gait_json_files_20250605210341/20120605T124837.json'
# Saved angles locally to: './processed_angles_data/100584/20120605T124837_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120605T124837'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120605T124837.json'
#
# Processing GCS blob: RunInjuryClinic/100608/20120628T105640.json
# Downloaded 'RunInjuryClinic/100608/20120628T105640.json' to 'temp_gait_json_files_20250605210341/20120628T105640.json'
# Saved angles locally to: './processed_angles_data/100608/20120628T105640_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120628T105640'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120628T105640.json'
#
# Processing GCS blob: RunInjuryClinic/100609/20120629T105939.json
# Downloaded 'RunInjuryClinic/100609/20120629T105939.json' to 'temp_gait_json_files_20250605210341/20120629T105939.json'
# Saved angles locally to: './processed_angles_data/100609/20120629T105939_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20120629T105939'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20120629T105939.json'
#
# ...
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20141203T160321.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200975/20141203T160321_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20141203T160321'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20141203T160321.json'
#
# Processing GCS blob: RunInjuryClinic/200976/20150115T152721.json
# Downloaded 'RunInjuryClinic/200976/20150115T152721.json' to 'temp_gait_json_files_20250605210341/20150115T152721.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150115T152721.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200976/20150115T152721_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150115T152721'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150115T152721.json'
#
# Processing GCS blob: RunInjuryClinic/200977/20150122T155921.json
# Downloaded 'RunInjuryClinic/200977/20150122T155921.json' to 'temp_gait_json_files_20250605210341/20150122T155921.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150122T155921.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200977/20150122T155921_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150122T155921'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150122T155921.json'
#
# Processing GCS blob: RunInjuryClinic/200979/20150204T090902.json
# Downloaded 'RunInjuryClinic/200979/20150204T090902.json' to 'temp_gait_json_files_20250605210341/20150204T090902.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150204T090902.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200979/20150204T090902_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150204T090902'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150204T090902.json'
#
# Processing GCS blob: RunInjuryClinic/200979/20150204T092428.json
# Downloaded 'RunInjuryClinic/200979/20150204T092428.json' to 'temp_gait_json_files_20250605210341/20150204T092428.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150204T092428.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200979/20150204T092428_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150204T092428'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150204T092428.json'
#
# Processing GCS blob: RunInjuryClinic/200980/20150204T105329.json
# Downloaded 'RunInjuryClinic/200980/20150204T105329.json' to 'temp_gait_json_files_20250605210341/20150204T105329.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150204T105329.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200980/20150204T105329_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150204T105329'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150204T105329.json'
#
# Processing GCS blob: RunInjuryClinic/200981/20150205T155950.json
# Downloaded 'RunInjuryClinic/200981/20150205T155950.json' to 'temp_gait_json_files_20250605210341/20150205T155950.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150205T155950.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200981/20150205T155950_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150205T155950'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150205T155950.json'
#
# Processing GCS blob: RunInjuryClinic/200981/20150205T161244.json
# Downloaded 'RunInjuryClinic/200981/20150205T161244.json' to 'temp_gait_json_files_20250605210341/20150205T161244.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150205T161244.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200981/20150205T161244_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150205T161244'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150205T161244.json'
#
# Processing GCS blob: RunInjuryClinic/200982/20150210T132555.json
# Downloaded 'RunInjuryClinic/200982/20150210T132555.json' to 'temp_gait_json_files_20250605210341/20150210T132555.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150210T132555.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200982/20150210T132555_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150210T132555'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150210T132555.json'
#
# Processing GCS blob: RunInjuryClinic/200983/20150219T124113.json
# Downloaded 'RunInjuryClinic/200983/20150219T124113.json' to 'temp_gait_json_files_20250605210341/20150219T124113.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150219T124113.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200983/20150219T124113_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150219T124113'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150219T124113.json'
#
# Processing GCS blob: RunInjuryClinic/200988/20150223T105910.json
# Downloaded 'RunInjuryClinic/200988/20150223T105910.json' to 'temp_gait_json_files_20250605210341/20150223T105910.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150223T105910.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200988/20150223T105910_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150223T105910'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150223T105910.json'
#
# Processing GCS blob: RunInjuryClinic/200984/20150226T133340.json
# Downloaded 'RunInjuryClinic/200984/20150226T133340.json' to 'temp_gait_json_files_20250605210341/20150226T133340.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150226T133340.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200984/20150226T133340_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150226T133340'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150226T133340.json'
#
# Processing GCS blob: RunInjuryClinic/200984/20150226T134106.json
# Downloaded 'RunInjuryClinic/200984/20150226T134106.json' to 'temp_gait_json_files_20250605210341/20150226T134106.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150226T134106.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200984/20150226T134106_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150226T134106'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150226T134106.json'
#
# Processing GCS blob: RunInjuryClinic/200989/20150303T134203.json
# Downloaded 'RunInjuryClinic/200989/20150303T134203.json' to 'temp_gait_json_files_20250605210341/20150303T134203.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150303T134203.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200989/20150303T134203_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150303T134203'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150303T134203.json'
#
# Processing GCS blob: RunInjuryClinic/200985/20150310T120115.json
# Downloaded 'RunInjuryClinic/200985/20150310T120115.json' to 'temp_gait_json_files_20250605210341/20150310T120115.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150310T120115.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200985/20150310T120115_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150310T120115'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150310T120115.json'
#
# Processing GCS blob: RunInjuryClinic/200985/20150310T121326.json
# Downloaded 'RunInjuryClinic/200985/20150310T121326.json' to 'temp_gait_json_files_20250605210341/20150310T121326.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150310T121326.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200985/20150310T121326_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150310T121326'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150310T121326.json'
#
# Processing GCS blob: RunInjuryClinic/200986/20150312T142834.json
# Downloaded 'RunInjuryClinic/200986/20150312T142834.json' to 'temp_gait_json_files_20250605210341/20150312T142834.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150312T142834.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200986/20150312T142834_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150312T142834'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150312T142834.json'
#
# Processing GCS blob: RunInjuryClinic/200986/20150312T143944.json
# Downloaded 'RunInjuryClinic/200986/20150312T143944.json' to 'temp_gait_json_files_20250605210341/20150312T143944.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150312T143944.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200986/20150312T143944_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150312T143944'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150312T143944.json'
#
# Processing GCS blob: RunInjuryClinic/200987/20150312T160840.json
# Downloaded 'RunInjuryClinic/200987/20150312T160840.json' to 'temp_gait_json_files_20250605210341/20150312T160840.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150312T160840.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/200987/20150312T160840_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150312T160840'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150312T160840.json'
#
# Processing GCS blob: RunInjuryClinic/201100/20150409T155915.json
# Downloaded 'RunInjuryClinic/201100/20150409T155915.json' to 'temp_gait_json_files_20250605210341/20150409T155915.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150409T155915.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/201100/20150409T155915_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150409T155915'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150409T155915.json'
#
# Processing GCS blob: RunInjuryClinic/201101/20150413T143152.json
# Downloaded 'RunInjuryClinic/201101/20150413T143152.json' to 'temp_gait_json_files_20250605210341/20150413T143152.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150413T143152.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/201101/20150413T143152_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150413T143152'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150413T143152.json'
#
# Processing GCS blob: RunInjuryClinic/201099/20150414T092041.json
# Downloaded 'RunInjuryClinic/201099/20150414T092041.json' to 'temp_gait_json_files_20250605210341/20150414T092041.json'
# Warning: Some required neutral tracking markers missing in temp_gait_json_files_20250605210341/20150414T092041.json
# Warning: Not enough valid neutral markers for L_foot cluster transformation.
# Warning: Not enough valid neutral markers for R_foot cluster transformation.
# Saved angles locally to: './processed_angles_data/201099/20150414T092041_angles.csv'
# Uploaded angles to BigQuery table: 'stridecare-461809.angle_csvs.angles_20150414T092041'
# Cleaned up local temporary JSON file: 'temp_gait_json_files_20250605210341/20150414T092041.json'
# Cleaned up temporary JSON download directory: 'temp_gait_json_files_20250605210341'
#
# Processing complete. Total files processed and outputted: 1832
